# %% [markdown]
# <a href="https://colab.research.google.com/github/Filarh/Fooocus/blob/main/cuaderno%20fooocus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 'Args' not in locals():
    # !pip install pygit2==1.12.2
    # %cd /content
    # !git clone https://github.com/lllyasviel/Fooocus.git
    # %cd /content/Fooocus
    Args = ""
# Importa la librería de Google Colab
import google.colab
import os
import json


# Check if Google Colab Drive needs to be activated
activar_drive = True #@param {type: "boolean"}

if activar_drive:
    from google.colab import drive
    drive.mount('/content/drive')
    # Desired paths
    nuevo_dir_lora = '/content/drive/MyDrive/MyLoras' #@param {type: "string"}
    nuevo_dir_salida = '/content/drive/MyDrive/Fooocus_output' #@param {type: "string"}

    # launch.py file
    launch_py_path = '/content/Fooocus/launch.py'

    # Check if the file exists
    if os.path.exists(launch_py_path):
        # Open the launch.py file
        with open(launch_py_path, 'r') as file:
            launch_py_content = file.read()

        # Code to insert at the beginning of launch.py
        codigo_a_insertar = f'''
import os
import json

# Updated paths
nuevo_dir_lora = '{nuevo_dir_lora}'
nuevo_dir_salida = '{nuevo_dir_salida}'

# Configuration file
config_path = os.path.abspath("./config.txt")
config_dict = {{}}

if os.path.exists(config_path):
    with open(config_path, "r", encoding="utf-8") as json_file:
        config_dict = json.load(json_file)

# Modify paths in the configuration dictionary
config_dict['path_loras'] = os.path.abspath(nuevo_dir_lora)
config_dict['path_outputs'] = os.path.abspath(nuevo_dir_salida)

# Save changes to the configuration file
with open(config_path, "w", encoding="utf-8") as json_file:
    json.dump(config_dict, json_file, indent=4)

'''

        # Write the new content at the beginning of launch.py
        with open(launch_py_path, 'w') as file:
            file.write(codigo_a_insertar + launch_py_content)
    else:
        print("The launch.py file does not exist in the provided location.")


#@markdown -------------

# Crea una sección para modificar el modelo por defecto
#@markdown ### **Modificación del modelo por defecto**
#@markdown Indica si quieres modificar el modelo por defecto o no. Si lo haces, proporciona el nombre del archivo, el link del archivo y el aspect ratio que deseas usar.
modificar_modelo = True #@param {type: "boolean"}
nombre_archivo = "zavychromaxl"  #@param {type: "string"}
link_archivo = "https://huggingface.co/rafationgson/zavychroma-xl-v4/resolve/main/zavychromaxl_v40.safetensors?download=true"  #@param {type: "string"}
aspect_ratio = "1152*896" #@param {type: "string"}

# Define una función para modificar el archivo JSON con los parámetros proporcionados
def modificar_json(nombre_archivo: str, link_archivo: str, aspect_ratio: str):
    carpeta = '/content/Fooocus/presets'
    archivos = os.listdir(carpeta)
    json_encontrado = next((archivo for archivo in archivos if archivo.endswith('.json')), None)

    if json_encontrado:
        with open(os.path.join(carpeta, json_encontrado)) as file:
            data = json.load(file)

        # Modificar los valores necesarios
        data['default_model'] = nombre_archivo + ".safetensors"  # Agregar la extensión al nombre del modelo
        data['default_aspect_ratio'] = aspect_ratio
        data['default_refiner'] = ""

        # Actualizar el diccionario checkpoint_downloads con el nuevo archivo y link
        data['checkpoint_downloads'] = {nombre_archivo + ".safetensors": link_archivo}  # Agregar la extensión al nombre del modelo

        # Establecer el argumento para la segunda celda basado en el nombre del archivo
        global Args
        Args = f"--preset {nombre_archivo}"  # Mantener solo el nombre del archivo sin extensión

        # Simplificar el nombre del archivo de salida
        nuevo_nombre = f"{nombre_archivo}.json"
        with open(os.path.join(carpeta, nuevo_nombre), 'w') as file:
            json.dump(data, file, separators=(',', ':'))

        return f"¡Se ha creado el archivo {nuevo_nombre} con los parámetros proporcionados y estructura correcta!"

    else:
        return "No se encontraron archivos JSON en la carpeta especificada."

# Si la variable es verdadera, llama a la función para modificar el JSON
if modificar_modelo:
  resultado = modificar_json(nombre_archivo, link_archivo, aspect_ratio)
  print(resultado)

#@markdown -------------
# Crea una sección para ejecutar el archivo entry_with_update.py con el argumento opcional para compartir los resultados
#@title Ejecución de entry_with_update.py
# !python entry_with_update.py --share $Args
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 5220, done.
# remote: Counting objects: 100% (301/301), done.
# remote: Compressing objects: 100% (294/294), done.
# remote: Total 5220 (delta 8), reused 292 (delta 4), pack-reused 4919
# Receiving objects: 100% (5220/5220), 32.22 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (3010/3010), done.
# /content/Fooocus
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ¡Se ha creado el archivo unstable.json con los parámetros proporcionados y estructura correcta!
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--preset', 'unstable']
# Loaded preset: /content/Fooocus/presets/unstable.json
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.862
# Installing requirements
# Downloading: "https://civitai.com/api/download/models/276923" to /content/Fooocus/models/checkpoints/unstable.safetensors
#
# 100% 6.46G/6.46G [02:54<00:00, 39.7MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 54.1MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 38.6MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xl-to-v1_interposer-v3.1.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v3.1.safetensors
#
# 100% 6.25M/6.25M [00:00<00:00, 236MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 257MB/s]
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: NORMAL_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Running on local URL:  http://127.0.0.1:7865
# 2024-01-09 17:38:14.124217: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-09 17:38:14.124323: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-09 17:38:14.258160: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Running on public URL: https://4ee4d37ec28e2c9dee.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 2024-01-09 17:38:16.532397: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids', 'cond_stage_model.clip_l.text_projection'}
# Base model loaded: /content/Fooocus/models/checkpoints/unstable.safetensors
# Request to load LoRAs [['SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors', 0.25], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/unstable.safetensors].
# Loaded LoRA [/content/drive/MyDrive/MyLoras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors] for UNet [/content/Fooocus/models/checkpoints/unstable.safetensors] with 788 keys at weight 0.25.
# Loaded LoRA [/content/drive/MyDrive/MyLoras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors] for CLIP [/content/Fooocus/models/checkpoints/unstable.safetensors] with 264 keys at weight 0.25.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.18 seconds
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://4ee4d37ec28e2c9dee.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 4904792212037844289
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [['Copia de sdxl_Mika-Rakul_Preet_Singh-000010.safetensors', 0.9], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/unstable.safetensors].
# Loaded LoRA [/content/drive/MyDrive/MyLoras/Copia de sdxl_Mika-Rakul_Preet_Singh-000010.safetensors] for UNet [/content/Fooocus/models/checkpoints/unstable.safetensors] with 722 keys at weight 0.9.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.06 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Rakul Preet Singh, portrayed in a stylized manga depiction forcefully split into four scenes arranged in a diagonal format. Scenes depict heavily stylized manga whimsy and exaggerated expressions, followed by a diagonally executed chaotic aftermath and exaggerated reactions. Forcefully realism, cluttered compositions, poorly executed humor, chaotic disorder, distorted facial expressions, inconsistent art styles, cinematic atmosphere
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Rakul Preet Singh, portrayed in a stylized manga depiction forcefully split into four scenes arranged in a diagonal format. Scenes depict heavily stylized manga whimsy and exaggerated expressions, followed by a diagonally executed chaotic aftermath and exaggerated reactions. Forcefully realism, cluttered compositions, poorly executed humor, chaotic disorder, distorted facial expressions, inconsistent art styles, creative
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 832)
# Preparation time: 12.09 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.83 seconds
# 100% 30/30 [00:25<00:00,  1.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.84 seconds
# Image generated with private log at: /content/drive/MyDrive/Fooocus_output/2024-01-09/log.html
# Generating and saving time: 32.72 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.16 seconds
# 100% 30/30 [00:25<00:00,  1.18it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.54 seconds
# Image generated with private log at: /content/drive/MyDrive/Fooocus_output/2024-01-09/log.html
# Generating and saving time: 30.44 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# Total time: 79.44 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 2610317326973868319
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Rakul Preet Singh, portrayed in a stylized anime depiction split into four scenes arranged diagonally. Scenes depict anime-style whimsy, exaggerated expressions, and a stylized chaotic aftermath with exaggerated reactions, created certain aesthetic colors, sharp focus, artistic, cinematic, highly detailed, intricate, very inspirational, innocent, authentic, romantic, vibrant, determined, loving
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Rakul Preet Singh, portrayed in a stylized anime depiction split into four scenes arranged diagonally. Scenes depict anime-style whimsy, exaggerated expressions, and a stylized chaotic aftermath with exaggerated reactions, sharp focus, detailed, professional composition, highly coherent, dramatic cinematic perfect romantic, beautiful, atmosphere, dynamic, lively, epic, very inspirational, real
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 832)
# Preparation time: 1.64 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.58 seconds
# 100% 30/30 [00:25<00:00,  1.19it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# Image generated with private log at: /content/drive/MyDrive/Fooocus_output/2024-01-09/log.html
# Generating and saving time: 30.67 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.82 seconds
# 100% 30/30 [00:24<00:00,  1.24it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Image generated with private log at: /content/drive/MyDrive/Fooocus_output/2024-01-09/log.html
# Generating and saving time: 28.96 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
# Total time: 65.11 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 742771337678722921
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Rakul Preet Singh, portrayed in a stylized anime depiction split into four scenes arranged diagonally. Scenes depict anime-style whimsy, exaggerated expressions, and a stylized chaotic aftermath with exaggerated reactions, detailed, sharp focus, real dramatic, cinematic, rich colors, artistic, highly nuanced, complex, stunning, surreal background, best, romantic, unique
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Rakul Preet Singh, portrayed in a stylized anime depiction split into four scenes arranged diagonally. Scenes depict anime-style whimsy, exaggerated expressions, and a stylized chaotic aftermath with exaggerated reactions, detailed, sharp focus, rich vibrant colors, ambient cinematic dramatic atmosphere, dynamic light, unique, refined, romantic, iconic, creative, fair composition, clear
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 832)
# Preparation time: 1.55 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.52 seconds
#  27% 8/30 [00:06<00:19,  1.15it/s]

# %%
# @title ##wipe
if 'Args' in locals():
    del Args

import shutil

fooocus_folder_path = '/content/Fooocus'

# Check if Fooocus folder exists and delete it
if shutil.os.path.exists(fooocus_folder_path):
    shutil.rmtree(fooocus_folder_path)
    print("Fooocus folder deleted.")
else:
    print("Fooocus folder not found.")
# Out:
# Fooocus folder deleted.
